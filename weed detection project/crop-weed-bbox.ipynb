# %%
import cv2 
import os
import gc
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow import keras
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt

shape = 224
classes = []

# %%
class Dataset:
    def __init__(self, shape):
        self.path = "./agri_data/data"
        self.data_files = os.listdir(self.path)
        self.data_csv = 0
        self.x_data = []
        self.y_bbox_data = []
        self.y_label_data = []
        self.x_data_files = []
        self.y_data_files = []
        self.labels = []
        self.shape = shape
        
    def __preprocessing_image(self, path):
        image = cv2.imread(path)
        image = cv2.resize(image, (shape, shape))
        image = np.reshape(image, (shape, shape, 3))
        image = np.array(image, dtype = "float32")
        image /= 255.0
        
        return image
        
    def __seperating_images_labels(self):
        for data_file in self.data_files:
            if data_file.split(".")[-1] == "txt":
                data = open(f"{self.path}/{data_file}", "r").readline().split()
                df = pd.DataFrame()
                df["filename"] = [data_file]
                df["class"] =[float(data[0])]
                df["xmin"] = [float(data[1])]
                df["ymin"] = [float(data[2])]
                df["xmax"] = [float(data[3])]
                df["ymax"] = [float(data[4])]
                self.y_data_files.append(df)
    
        self.data_csv = pd.concat(self.y_data_files)
        for i in list(self.data_csv.columns[2:]):
            self.data_csv[i] = self.data_csv[i].astype(float)
            
    def __extract_images(self):
        self.images_paths = self.data_csv["filename"].values
        for image in self.images_paths:
            self.x_data.append(self.__preprocessing_image(self.path + "/" + image.split(".")[0] + ".jpeg"))
            
    def __extract_labels(self):
        global classes
        self.classes = self.data_csv["class"].unique().tolist()
        classes = self.classes
        self.y_label_data = self.data_csv["class"].values
        self.y_label_data = [self.classes.index(i) for i in self.y_label_data]
        self.y_label_data = keras.utils.to_categorical(self.y_label_data)
        self.y_label_data = np.array(self.y_label_data, dtype = "float32")
        
    def __extract_bboxes(self):
        for index, _ in enumerate(self.data_csv["xmin"].values):
            self.y_bbox_data.append(self.data_csv.iloc[[index]].values[0])
        self.y_bbox_data = np.array(self.y_bbox_data, dtype= "float32")
            
    def load_data(self):
        self.__seperating_images_labels()
        self.__extract_labels()
        self.__extract_images()
        self.data_csv = self.data_csv.drop('class', axis = 1)
        self.data_csv = self.data_csv.drop('filename', axis = 1)
        self.__extract_bboxes()
        
        return train_test_split(self.x_data, self.y_label_data, self.y_bbox_data, random_state = 42, shuffle = True)

dataset = Dataset(shape)
split = dataset.load_data()

# %%
(x_train, x_test) = split[:2]
(y_class_train, y_class_test) = split[2:4]
(y_bbox_train, y_bbox_test) = split[4:]
x_train = np.array(x_train, dtype = "float32")
x_test = np.array(x_test, dtype = "float32")
#y_bbox_train = np.reshape(y_bbox_train, (y_bbox_train.shape[0], 4))
#y_bbox_test =  np.reshape(y_bbox_test,  (y_bbox_test.shape[0], 4))
y_bbox_train = np.array(y_bbox_train, dtype = "float32")
y_bbox_test = np.array(y_bbox_test, dtype = "float32")
y_class_train = np.array(y_class_train, dtype = "float32")
y_class_test = np.array(y_class_test, dtype = "float32")

print(f"X_Train Shape : {x_train.shape}")
print(f"X_Test Shape : {x_test.shape}")
print(f"Y_class_Train Shape : {y_class_train.shape}")
print(f"Y_class_Test Shape : {y_class_test.shape}")
print(f"Y_bbox_Train Shape : {y_bbox_train.shape}")
print(f"Y_bbox_Test Shape : {y_bbox_test.shape}")

del dataset
del split
gc.collect()
# Out:
# X_Train Shape : (975, 224, 224, 3)
# X_Test Shape : (325, 224, 224, 3)
# Y_class_Train Shape : (975, 2)
# Y_class_Test Shape : (325, 2)
# Y_bbox_Train Shape : (975, 4)
# Y_bbox_Test Shape : (325, 4)
# 21

# %%
class Model():
    def __init__(self, cnn):
        self.model_input1 = keras.layers.Input((shape, shape, 3))
        self.cnn = cnn(weights = "imagenet", include_top = False, input_tensor = self.model_input1)
        for layer in self.cnn.layers:
            layer.trainable = False
        self.__build_model()
        self.plot_loss_acc()
        
    def __build_model(self):
        
        flatten = keras.layers.Flatten()(self.cnn.output)
        x = keras.layers.Dense(1024, activation = "relu", kernel_initializer ="he_normal")(flatten)
        x = keras.layers.Dense(512, activation = "relu", kernel_initializer = "he_normal")(x)
        x = keras.layers.Dense(256, activation = "relu", kernel_initializer = "he_normal")(x)
        x = keras.layers.Dense(128, activation = "relu", kernel_initializer = "he_normal")(x)
        output_1 = keras.layers.Dense(len(classes), activation = "softmax", name = "Class")(x)
        
        x = keras.layers.Dense(256, activation = "relu", kernel_initializer ="he_normal")(flatten)
        x = keras.layers.Dense(128, activation = "relu", kernel_initializer ="he_normal")(x)
        x = keras.layers.Dense(64, activation = "relu", kernel_initializer = "he_normal")(x)
        x = keras.layers.Dense(32, activation = "relu", kernel_initializer = "he_normal")(x)
        output_2 = keras.layers.Dense(4, activation = "sigmoid", name = "BBOX")(x)
        
        optimizer = keras.optimizers.Adam(1e-4)
        self.model = keras.models.Model(inputs = [self.model_input1], outputs = [output_1, output_2])
        losses = {"Class": "categorical_crossentropy","BBOX": "mse"}
        lossWeights = {"Class": 1.0, "BBOX": 1.0}
        self.model.compile(optimizer = optimizer, loss = losses, metrics = ["accuracy"])
        
        #display(keras.utils.plot_model(self.model))
        checkpoint = keras.callbacks.ModelCheckpoint("./model.h5")
        
        self.model.fit(x_train, y = {"Class":y_class_train, "BBOX":y_bbox_train},
                       epochs = 100, validation_data = (x_test, {"Class":y_class_test, "BBOX":y_bbox_test}),
                       shuffle = True, callbacks = [checkpoint])
    
    def plot_loss_acc(self):
        #Loss vs Epochs
        plt.plot(self.model.history.history['Class_loss'], label='train')
        plt.plot(self.model.history.history['val_Class_loss'], label='test')
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title(f"Loss vs Epochs")
        plt.legend()
        plt.show()
        #Accuracy vs Epochs
        plt.plot(self.model.history.history['Class_accuracy'], label='train')
        plt.plot(self.model.history.history['val_Class_accuracy'], label='test')
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        plt.title(f"ACCURACY vs Epochs")
        plt.legend()
        plt.show()

# %%
model = Model(keras.applications.resnet.ResNet101)
# Out:
# 2022-09-19 13:30:01.232010: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09-19 13:30:01.235932: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-09-19 13:30:01.306362: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:01.307616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2022-09-19 13:30:01.307717: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-09-19 13:30:01.354536: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-09-19 13:30:01.354680: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-09-19 13:30:01.381067: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-09-19 13:30:01.390355: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-09-19 13:30:01.419811: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-09-19 13:30:01.429500: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-09-19 13:30:01.432513: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-09-19 13:30:01.432776: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:01.433733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:01.435408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-09-19 13:30:01.435917: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-19 13:30:01.436185: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09-19 13:30:01.436413: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:01.437135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2022-09-19 13:30:01.437238: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-09-19 13:30:01.437279: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-09-19 13:30:01.437306: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-09-19 13:30:01.437334: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-09-19 13:30:01.437383: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-09-19 13:30:01.437414: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-09-19 13:30:01.437441: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-09-19 13:30:01.437468: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-09-19 13:30:01.437579: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:01.438427: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:01.439108: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-09-19 13:30:01.440328: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-09-19 13:30:03.190730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-19 13:30:03.190805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-09-19 13:30:03.190819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-09-19 13:30:03.193104: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:03.193950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:03.194636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 13:30:03.195410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 3s 0us/step
# 2022-09-19 13:30:10.014623: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-09-19 13:30:10.027696: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000160000 Hz
# Epoch 1/100
# 2022-09-19 13:30:16.049989: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-09-19 13:30:16.927772: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-09-19 13:30:16.964005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 31/31 [==============================] - 20s 238ms/step - loss: 1.4997 - Class_loss: 1.4441 - BBOX_loss: 0.0556 - Class_accuracy: 0.5375 - BBOX_accuracy: 0.4257 - val_loss: 0.6086 - val_Class_loss: 0.5846 - val_BBOX_loss: 0.0241 - val_Class_accuracy: 0.7138 - val_BBOX_accuracy: 0.5908
# Epoch 2/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.6932 - Class_loss: 0.6672 - BBOX_loss: 0.0260 - Class_accuracy: 0.6225 - BBOX_accuracy: 0.5440 - val_loss: 0.6307 - val_Class_loss: 0.6077 - val_BBOX_loss: 0.0231 - val_Class_accuracy: 0.5908 - val_BBOX_accuracy: 0.4769
# Epoch 3/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.6192 - Class_loss: 0.5955 - BBOX_loss: 0.0237 - Class_accuracy: 0.6412 - BBOX_accuracy: 0.5394 - val_loss: 0.4788 - val_Class_loss: 0.4588 - val_BBOX_loss: 0.0200 - val_Class_accuracy: 0.8431 - val_BBOX_accuracy: 0.6062
# Epoch 4/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.4653 - Class_loss: 0.4413 - BBOX_loss: 0.0240 - Class_accuracy: 0.8461 - BBOX_accuracy: 0.5678 - val_loss: 0.4363 - val_Class_loss: 0.4168 - val_BBOX_loss: 0.0195 - val_Class_accuracy: 0.8677 - val_BBOX_accuracy: 0.5169
# Epoch 5/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.4589 - Class_loss: 0.4364 - BBOX_loss: 0.0224 - Class_accuracy: 0.8102 - BBOX_accuracy: 0.5787 - val_loss: 0.4443 - val_Class_loss: 0.4267 - val_BBOX_loss: 0.0175 - val_Class_accuracy: 0.8277 - val_BBOX_accuracy: 0.6031
# Epoch 6/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.3805 - Class_loss: 0.3603 - BBOX_loss: 0.0202 - Class_accuracy: 0.8762 - BBOX_accuracy: 0.5853 - val_loss: 0.3688 - val_Class_loss: 0.3515 - val_BBOX_loss: 0.0173 - val_Class_accuracy: 0.9015 - val_BBOX_accuracy: 0.6154
# Epoch 7/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.3577 - Class_loss: 0.3382 - BBOX_loss: 0.0194 - Class_accuracy: 0.8665 - BBOX_accuracy: 0.5966 - val_loss: 0.4138 - val_Class_loss: 0.3953 - val_BBOX_loss: 0.0185 - val_Class_accuracy: 0.8400 - val_BBOX_accuracy: 0.6031
# Epoch 8/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.3358 - Class_loss: 0.3171 - BBOX_loss: 0.0187 - Class_accuracy: 0.8625 - BBOX_accuracy: 0.5571 - val_loss: 0.3361 - val_Class_loss: 0.3192 - val_BBOX_loss: 0.0169 - val_Class_accuracy: 0.8923 - val_BBOX_accuracy: 0.6369
# Epoch 9/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.3342 - Class_loss: 0.3161 - BBOX_loss: 0.0180 - Class_accuracy: 0.8825 - BBOX_accuracy: 0.5914 - val_loss: 0.2998 - val_Class_loss: 0.2845 - val_BBOX_loss: 0.0153 - val_Class_accuracy: 0.8985 - val_BBOX_accuracy: 0.6338
# Epoch 10/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.2556 - Class_loss: 0.2389 - BBOX_loss: 0.0167 - Class_accuracy: 0.9295 - BBOX_accuracy: 0.5816 - val_loss: 0.3508 - val_Class_loss: 0.3334 - val_BBOX_loss: 0.0174 - val_Class_accuracy: 0.8800 - val_BBOX_accuracy: 0.6246
# Epoch 11/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.2959 - Class_loss: 0.2794 - BBOX_loss: 0.0165 - Class_accuracy: 0.9005 - BBOX_accuracy: 0.5602 - val_loss: 0.3234 - val_Class_loss: 0.3086 - val_BBOX_loss: 0.0148 - val_Class_accuracy: 0.8954 - val_BBOX_accuracy: 0.6277
# Epoch 12/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.3041 - Class_loss: 0.2872 - BBOX_loss: 0.0169 - Class_accuracy: 0.8822 - BBOX_accuracy: 0.5711 - val_loss: 0.3618 - val_Class_loss: 0.3464 - val_BBOX_loss: 0.0155 - val_Class_accuracy: 0.8769 - val_BBOX_accuracy: 0.6369
# Epoch 13/100
# 31/31 [==============================] - 5s 148ms/step - loss: 0.3211 - Class_loss: 0.3058 - BBOX_loss: 0.0153 - Class_accuracy: 0.8839 - BBOX_accuracy: 0.6282 - val_loss: 0.3118 - val_Class_loss: 0.2973 - val_BBOX_loss: 0.0146 - val_Class_accuracy: 0.8985 - val_BBOX_accuracy: 0.6462
# Epoch 14/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.2482 - Class_loss: 0.2338 - BBOX_loss: 0.0144 - Class_accuracy: 0.9193 - BBOX_accuracy: 0.6142 - val_loss: 0.2604 - val_Class_loss: 0.2464 - val_BBOX_loss: 0.0139 - val_Class_accuracy: 0.9231 - val_BBOX_accuracy: 0.6492
# Epoch 15/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.2187 - Class_loss: 0.2041 - BBOX_loss: 0.0147 - Class_accuracy: 0.9331 - BBOX_accuracy: 0.6043 - val_loss: 0.7402 - val_Class_loss: 0.7256 - val_BBOX_loss: 0.0146 - val_Class_accuracy: 0.6677 - val_BBOX_accuracy: 0.6400
# Epoch 16/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.4110 - Class_loss: 0.3947 - BBOX_loss: 0.0163 - Class_accuracy: 0.8040 - BBOX_accuracy: 0.5777 - val_loss: 0.3150 - val_Class_loss: 0.2964 - val_BBOX_loss: 0.0186 - val_Class_accuracy: 0.8985 - val_BBOX_accuracy: 0.6123
# Epoch 17/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.2324 - Class_loss: 0.2169 - BBOX_loss: 0.0156 - Class_accuracy: 0.9310 - BBOX_accuracy: 0.6194 - val_loss: 0.2590 - val_Class_loss: 0.2435 - val_BBOX_loss: 0.0156 - val_Class_accuracy: 0.9262 - val_BBOX_accuracy: 0.6523
# Epoch 18/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.2294 - Class_loss: 0.2141 - BBOX_loss: 0.0153 - Class_accuracy: 0.9309 - BBOX_accuracy: 0.6005 - val_loss: 0.2518 - val_Class_loss: 0.2342 - val_BBOX_loss: 0.0176 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.5231
# Epoch 19/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.2394 - Class_loss: 0.2247 - BBOX_loss: 0.0147 - Class_accuracy: 0.9200 - BBOX_accuracy: 0.6006 - val_loss: 0.3668 - val_Class_loss: 0.3539 - val_BBOX_loss: 0.0130 - val_Class_accuracy: 0.8677 - val_BBOX_accuracy: 0.6646
# Epoch 20/100
# 31/31 [==============================] - 4s 146ms/step - loss: 0.2363 - Class_loss: 0.2239 - BBOX_loss: 0.0124 - Class_accuracy: 0.9141 - BBOX_accuracy: 0.6303 - val_loss: 0.2458 - val_Class_loss: 0.2323 - val_BBOX_loss: 0.0135 - val_Class_accuracy: 0.9292 - val_BBOX_accuracy: 0.6215
# Epoch 21/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.1527 - Class_loss: 0.1395 - BBOX_loss: 0.0132 - Class_accuracy: 0.9595 - BBOX_accuracy: 0.6129 - val_loss: 0.2487 - val_Class_loss: 0.2345 - val_BBOX_loss: 0.0142 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6615
# Epoch 22/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.1964 - Class_loss: 0.1832 - BBOX_loss: 0.0132 - Class_accuracy: 0.9429 - BBOX_accuracy: 0.6313 - val_loss: 0.3252 - val_Class_loss: 0.3117 - val_BBOX_loss: 0.0135 - val_Class_accuracy: 0.8800 - val_BBOX_accuracy: 0.6246
# Epoch 23/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.2205 - Class_loss: 0.2070 - BBOX_loss: 0.0136 - Class_accuracy: 0.9139 - BBOX_accuracy: 0.6359 - val_loss: 0.2571 - val_Class_loss: 0.2430 - val_BBOX_loss: 0.0141 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6677
# Epoch 24/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.2255 - Class_loss: 0.2131 - BBOX_loss: 0.0124 - Class_accuracy: 0.9236 - BBOX_accuracy: 0.6510 - val_loss: 0.2373 - val_Class_loss: 0.2203 - val_BBOX_loss: 0.0171 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.5815
# Epoch 25/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.1627 - Class_loss: 0.1489 - BBOX_loss: 0.0138 - Class_accuracy: 0.9529 - BBOX_accuracy: 0.6393 - val_loss: 0.2782 - val_Class_loss: 0.2638 - val_BBOX_loss: 0.0144 - val_Class_accuracy: 0.9138 - val_BBOX_accuracy: 0.6000
# Epoch 26/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.1458 - Class_loss: 0.1331 - BBOX_loss: 0.0126 - Class_accuracy: 0.9655 - BBOX_accuracy: 0.6409 - val_loss: 0.3038 - val_Class_loss: 0.2909 - val_BBOX_loss: 0.0128 - val_Class_accuracy: 0.9015 - val_BBOX_accuracy: 0.6585
# Epoch 27/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.1301 - Class_loss: 0.1184 - BBOX_loss: 0.0117 - Class_accuracy: 0.9728 - BBOX_accuracy: 0.6567 - val_loss: 0.2583 - val_Class_loss: 0.2403 - val_BBOX_loss: 0.0180 - val_Class_accuracy: 0.9292 - val_BBOX_accuracy: 0.5815
# Epoch 28/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.1870 - Class_loss: 0.1709 - BBOX_loss: 0.0161 - Class_accuracy: 0.9418 - BBOX_accuracy: 0.5899 - val_loss: 0.2738 - val_Class_loss: 0.2598 - val_BBOX_loss: 0.0139 - val_Class_accuracy: 0.9169 - val_BBOX_accuracy: 0.6369
# Epoch 29/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.1505 - Class_loss: 0.1379 - BBOX_loss: 0.0126 - Class_accuracy: 0.9590 - BBOX_accuracy: 0.6144 - val_loss: 0.3777 - val_Class_loss: 0.3655 - val_BBOX_loss: 0.0122 - val_Class_accuracy: 0.8769 - val_BBOX_accuracy: 0.6585
# Epoch 30/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.1814 - Class_loss: 0.1696 - BBOX_loss: 0.0119 - Class_accuracy: 0.9452 - BBOX_accuracy: 0.6310 - val_loss: 0.2408 - val_Class_loss: 0.2275 - val_BBOX_loss: 0.0133 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6615
# Epoch 31/100
# 31/31 [==============================] - 4s 146ms/step - loss: 0.3048 - Class_loss: 0.2926 - BBOX_loss: 0.0122 - Class_accuracy: 0.8772 - BBOX_accuracy: 0.6384 - val_loss: 0.2513 - val_Class_loss: 0.2378 - val_BBOX_loss: 0.0135 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6523
# Epoch 32/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.1482 - Class_loss: 0.1362 - BBOX_loss: 0.0120 - Class_accuracy: 0.9597 - BBOX_accuracy: 0.6465 - val_loss: 0.2374 - val_Class_loss: 0.2256 - val_BBOX_loss: 0.0118 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6554
# Epoch 33/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.1315 - Class_loss: 0.1208 - BBOX_loss: 0.0106 - Class_accuracy: 0.9609 - BBOX_accuracy: 0.6758 - val_loss: 0.2319 - val_Class_loss: 0.2136 - val_BBOX_loss: 0.0184 - val_Class_accuracy: 0.9446 - val_BBOX_accuracy: 0.6400
# Epoch 34/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.2135 - Class_loss: 0.1986 - BBOX_loss: 0.0149 - Class_accuracy: 0.9298 - BBOX_accuracy: 0.6217 - val_loss: 0.2438 - val_Class_loss: 0.2293 - val_BBOX_loss: 0.0144 - val_Class_accuracy: 0.9292 - val_BBOX_accuracy: 0.6431
# Epoch 35/100
# 31/31 [==============================] - 4s 140ms/step - loss: 0.1717 - Class_loss: 0.1606 - BBOX_loss: 0.0111 - Class_accuracy: 0.9373 - BBOX_accuracy: 0.6394 - val_loss: 0.2419 - val_Class_loss: 0.2237 - val_BBOX_loss: 0.0183 - val_Class_accuracy: 0.9446 - val_BBOX_accuracy: 0.6400
# Epoch 36/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.1198 - Class_loss: 0.1059 - BBOX_loss: 0.0139 - Class_accuracy: 0.9662 - BBOX_accuracy: 0.6067 - val_loss: 0.2692 - val_Class_loss: 0.2568 - val_BBOX_loss: 0.0124 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6492
# Epoch 37/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.1133 - Class_loss: 0.1019 - BBOX_loss: 0.0114 - Class_accuracy: 0.9721 - BBOX_accuracy: 0.6523 - val_loss: 0.2324 - val_Class_loss: 0.2163 - val_BBOX_loss: 0.0161 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6523
# Epoch 38/100
# 31/31 [==============================] - 4s 146ms/step - loss: 0.2003 - Class_loss: 0.1880 - BBOX_loss: 0.0123 - Class_accuracy: 0.9282 - BBOX_accuracy: 0.6286 - val_loss: 0.5758 - val_Class_loss: 0.5645 - val_BBOX_loss: 0.0112 - val_Class_accuracy: 0.7908 - val_BBOX_accuracy: 0.6769
# Epoch 39/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.2274 - Class_loss: 0.2176 - BBOX_loss: 0.0098 - Class_accuracy: 0.8948 - BBOX_accuracy: 0.6594 - val_loss: 0.2560 - val_Class_loss: 0.2447 - val_BBOX_loss: 0.0113 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6677
# Epoch 40/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.1235 - Class_loss: 0.1142 - BBOX_loss: 0.0094 - Class_accuracy: 0.9714 - BBOX_accuracy: 0.6412 - val_loss: 0.2354 - val_Class_loss: 0.2241 - val_BBOX_loss: 0.0113 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6523
# Epoch 41/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.1688 - Class_loss: 0.1598 - BBOX_loss: 0.0091 - Class_accuracy: 0.9366 - BBOX_accuracy: 0.6924 - val_loss: 0.2465 - val_Class_loss: 0.2351 - val_BBOX_loss: 0.0114 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6615
# Epoch 42/100
# 31/31 [==============================] - 5s 149ms/step - loss: 0.1224 - Class_loss: 0.1135 - BBOX_loss: 0.0089 - Class_accuracy: 0.9677 - BBOX_accuracy: 0.6587 - val_loss: 0.2850 - val_Class_loss: 0.2740 - val_BBOX_loss: 0.0111 - val_Class_accuracy: 0.9077 - val_BBOX_accuracy: 0.6431
# Epoch 43/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.1219 - Class_loss: 0.1120 - BBOX_loss: 0.0099 - Class_accuracy: 0.9681 - BBOX_accuracy: 0.6639 - val_loss: 0.2707 - val_Class_loss: 0.2591 - val_BBOX_loss: 0.0116 - val_Class_accuracy: 0.9262 - val_BBOX_accuracy: 0.6277
# Epoch 44/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.1494 - Class_loss: 0.1402 - BBOX_loss: 0.0093 - Class_accuracy: 0.9501 - BBOX_accuracy: 0.6985 - val_loss: 0.5893 - val_Class_loss: 0.5783 - val_BBOX_loss: 0.0110 - val_Class_accuracy: 0.7908 - val_BBOX_accuracy: 0.6462
# Epoch 45/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.2339 - Class_loss: 0.2244 - BBOX_loss: 0.0096 - Class_accuracy: 0.9137 - BBOX_accuracy: 0.6482 - val_loss: 0.2305 - val_Class_loss: 0.2189 - val_BBOX_loss: 0.0116 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6492
# Epoch 46/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0893 - Class_loss: 0.0794 - BBOX_loss: 0.0099 - Class_accuracy: 0.9689 - BBOX_accuracy: 0.6528 - val_loss: 0.2404 - val_Class_loss: 0.2296 - val_BBOX_loss: 0.0108 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6800
# Epoch 47/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.1235 - Class_loss: 0.1145 - BBOX_loss: 0.0090 - Class_accuracy: 0.9659 - BBOX_accuracy: 0.6861 - val_loss: 0.2408 - val_Class_loss: 0.2294 - val_BBOX_loss: 0.0114 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6523
# Epoch 48/100
# 31/31 [==============================] - 4s 140ms/step - loss: 0.0953 - Class_loss: 0.0870 - BBOX_loss: 0.0083 - Class_accuracy: 0.9772 - BBOX_accuracy: 0.6919 - val_loss: 0.2407 - val_Class_loss: 0.2300 - val_BBOX_loss: 0.0107 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6800
# Epoch 49/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0803 - Class_loss: 0.0707 - BBOX_loss: 0.0097 - Class_accuracy: 0.9765 - BBOX_accuracy: 0.6945 - val_loss: 0.2410 - val_Class_loss: 0.2301 - val_BBOX_loss: 0.0109 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6554
# Epoch 50/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.1765 - Class_loss: 0.1676 - BBOX_loss: 0.0090 - Class_accuracy: 0.9355 - BBOX_accuracy: 0.6435 - val_loss: 0.5070 - val_Class_loss: 0.4957 - val_BBOX_loss: 0.0113 - val_Class_accuracy: 0.8308 - val_BBOX_accuracy: 0.6615
# Epoch 51/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.2924 - Class_loss: 0.2841 - BBOX_loss: 0.0083 - Class_accuracy: 0.8744 - BBOX_accuracy: 0.6716 - val_loss: 0.2357 - val_Class_loss: 0.2245 - val_BBOX_loss: 0.0111 - val_Class_accuracy: 0.9508 - val_BBOX_accuracy: 0.6831
# Epoch 52/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0937 - Class_loss: 0.0856 - BBOX_loss: 0.0081 - Class_accuracy: 0.9810 - BBOX_accuracy: 0.6993 - val_loss: 0.2772 - val_Class_loss: 0.2664 - val_BBOX_loss: 0.0108 - val_Class_accuracy: 0.9169 - val_BBOX_accuracy: 0.6677
# Epoch 53/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.1329 - Class_loss: 0.1246 - BBOX_loss: 0.0083 - Class_accuracy: 0.9618 - BBOX_accuracy: 0.6943 - val_loss: 0.2280 - val_Class_loss: 0.2171 - val_BBOX_loss: 0.0109 - val_Class_accuracy: 0.9477 - val_BBOX_accuracy: 0.6462
# Epoch 54/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.1511 - Class_loss: 0.1425 - BBOX_loss: 0.0086 - Class_accuracy: 0.9463 - BBOX_accuracy: 0.6956 - val_loss: 0.2360 - val_Class_loss: 0.2245 - val_BBOX_loss: 0.0115 - val_Class_accuracy: 0.9508 - val_BBOX_accuracy: 0.6677
# Epoch 55/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0871 - Class_loss: 0.0785 - BBOX_loss: 0.0087 - Class_accuracy: 0.9797 - BBOX_accuracy: 0.6995 - val_loss: 0.2660 - val_Class_loss: 0.2556 - val_BBOX_loss: 0.0104 - val_Class_accuracy: 0.9200 - val_BBOX_accuracy: 0.6738
# Epoch 56/100
# 31/31 [==============================] - 5s 148ms/step - loss: 0.1055 - Class_loss: 0.0967 - BBOX_loss: 0.0088 - Class_accuracy: 0.9668 - BBOX_accuracy: 0.6509 - val_loss: 0.4205 - val_Class_loss: 0.4094 - val_BBOX_loss: 0.0111 - val_Class_accuracy: 0.8585 - val_BBOX_accuracy: 0.6554
# Epoch 57/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.1193 - Class_loss: 0.1116 - BBOX_loss: 0.0077 - Class_accuracy: 0.9646 - BBOX_accuracy: 0.6886 - val_loss: 0.2365 - val_Class_loss: 0.2229 - val_BBOX_loss: 0.0136 - val_Class_accuracy: 0.9508 - val_BBOX_accuracy: 0.6769
# Epoch 58/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.1319 - Class_loss: 0.1224 - BBOX_loss: 0.0096 - Class_accuracy: 0.9688 - BBOX_accuracy: 0.6725 - val_loss: 0.4039 - val_Class_loss: 0.3931 - val_BBOX_loss: 0.0108 - val_Class_accuracy: 0.8892 - val_BBOX_accuracy: 0.6677
# Epoch 59/100
# 31/31 [==============================] - 4s 146ms/step - loss: 0.1905 - Class_loss: 0.1829 - BBOX_loss: 0.0076 - Class_accuracy: 0.9292 - BBOX_accuracy: 0.6853 - val_loss: 0.2640 - val_Class_loss: 0.2481 - val_BBOX_loss: 0.0159 - val_Class_accuracy: 0.9138 - val_BBOX_accuracy: 0.6462
# Epoch 60/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.3269 - Class_loss: 0.3182 - BBOX_loss: 0.0088 - Class_accuracy: 0.8692 - BBOX_accuracy: 0.6854 - val_loss: 0.2315 - val_Class_loss: 0.2211 - val_BBOX_loss: 0.0104 - val_Class_accuracy: 0.9508 - val_BBOX_accuracy: 0.6800
# Epoch 61/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.1142 - Class_loss: 0.1066 - BBOX_loss: 0.0076 - Class_accuracy: 0.9678 - BBOX_accuracy: 0.6890 - val_loss: 0.3386 - val_Class_loss: 0.3265 - val_BBOX_loss: 0.0120 - val_Class_accuracy: 0.8831 - val_BBOX_accuracy: 0.5754
# Epoch 62/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.1857 - Class_loss: 0.1784 - BBOX_loss: 0.0073 - Class_accuracy: 0.9408 - BBOX_accuracy: 0.7133 - val_loss: 0.2512 - val_Class_loss: 0.2402 - val_BBOX_loss: 0.0110 - val_Class_accuracy: 0.9262 - val_BBOX_accuracy: 0.6708
# Epoch 63/100
# 31/31 [==============================] - 4s 146ms/step - loss: 0.1096 - Class_loss: 0.1023 - BBOX_loss: 0.0074 - Class_accuracy: 0.9757 - BBOX_accuracy: 0.7199 - val_loss: 0.2342 - val_Class_loss: 0.2231 - val_BBOX_loss: 0.0111 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6554
# Epoch 64/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0676 - Class_loss: 0.0596 - BBOX_loss: 0.0081 - Class_accuracy: 0.9802 - BBOX_accuracy: 0.6712 - val_loss: 0.2487 - val_Class_loss: 0.2347 - val_BBOX_loss: 0.0140 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6677
# Epoch 65/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.1011 - Class_loss: 0.0921 - BBOX_loss: 0.0091 - Class_accuracy: 0.9715 - BBOX_accuracy: 0.6854 - val_loss: 0.3023 - val_Class_loss: 0.2917 - val_BBOX_loss: 0.0106 - val_Class_accuracy: 0.9015 - val_BBOX_accuracy: 0.6615
# Epoch 66/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.0759 - Class_loss: 0.0693 - BBOX_loss: 0.0066 - Class_accuracy: 0.9832 - BBOX_accuracy: 0.7360 - val_loss: 0.2503 - val_Class_loss: 0.2392 - val_BBOX_loss: 0.0111 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6831
# Epoch 67/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0833 - Class_loss: 0.0763 - BBOX_loss: 0.0070 - Class_accuracy: 0.9768 - BBOX_accuracy: 0.7223 - val_loss: 0.2341 - val_Class_loss: 0.2240 - val_BBOX_loss: 0.0101 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6738
# Epoch 68/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.0541 - Class_loss: 0.0477 - BBOX_loss: 0.0063 - Class_accuracy: 0.9829 - BBOX_accuracy: 0.7350 - val_loss: 0.3460 - val_Class_loss: 0.3348 - val_BBOX_loss: 0.0112 - val_Class_accuracy: 0.8954 - val_BBOX_accuracy: 0.6738
# Epoch 69/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0877 - Class_loss: 0.0797 - BBOX_loss: 0.0080 - Class_accuracy: 0.9715 - BBOX_accuracy: 0.7031 - val_loss: 0.2570 - val_Class_loss: 0.2456 - val_BBOX_loss: 0.0114 - val_Class_accuracy: 0.9323 - val_BBOX_accuracy: 0.6677
# Epoch 70/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.1050 - Class_loss: 0.0976 - BBOX_loss: 0.0074 - Class_accuracy: 0.9670 - BBOX_accuracy: 0.7223 - val_loss: 0.5015 - val_Class_loss: 0.4894 - val_BBOX_loss: 0.0121 - val_Class_accuracy: 0.8523 - val_BBOX_accuracy: 0.6708
# Epoch 71/100
# 31/31 [==============================] - 4s 146ms/step - loss: 0.1072 - Class_loss: 0.1006 - BBOX_loss: 0.0066 - Class_accuracy: 0.9666 - BBOX_accuracy: 0.7137 - val_loss: 0.2736 - val_Class_loss: 0.2633 - val_BBOX_loss: 0.0103 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6677
# Epoch 72/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0852 - Class_loss: 0.0778 - BBOX_loss: 0.0074 - Class_accuracy: 0.9686 - BBOX_accuracy: 0.6753 - val_loss: 0.5514 - val_Class_loss: 0.5394 - val_BBOX_loss: 0.0120 - val_Class_accuracy: 0.8308 - val_BBOX_accuracy: 0.6000
# Epoch 73/100
# 31/31 [==============================] - 5s 152ms/step - loss: 0.1836 - Class_loss: 0.1748 - BBOX_loss: 0.0087 - Class_accuracy: 0.9271 - BBOX_accuracy: 0.6695 - val_loss: 0.2521 - val_Class_loss: 0.2406 - val_BBOX_loss: 0.0114 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6738
# Epoch 74/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.0391 - Class_loss: 0.0326 - BBOX_loss: 0.0065 - Class_accuracy: 0.9932 - BBOX_accuracy: 0.7141 - val_loss: 0.2845 - val_Class_loss: 0.2732 - val_BBOX_loss: 0.0113 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6246
# Epoch 75/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0823 - Class_loss: 0.0765 - BBOX_loss: 0.0058 - Class_accuracy: 0.9743 - BBOX_accuracy: 0.7178 - val_loss: 0.2764 - val_Class_loss: 0.2662 - val_BBOX_loss: 0.0102 - val_Class_accuracy: 0.9477 - val_BBOX_accuracy: 0.6923
# Epoch 76/100
# 31/31 [==============================] - 4s 146ms/step - loss: 0.3148 - Class_loss: 0.3088 - BBOX_loss: 0.0059 - Class_accuracy: 0.8857 - BBOX_accuracy: 0.7213 - val_loss: 0.2938 - val_Class_loss: 0.2829 - val_BBOX_loss: 0.0109 - val_Class_accuracy: 0.9262 - val_BBOX_accuracy: 0.6862
# Epoch 77/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.1169 - Class_loss: 0.1105 - BBOX_loss: 0.0063 - Class_accuracy: 0.9540 - BBOX_accuracy: 0.7038 - val_loss: 0.3078 - val_Class_loss: 0.2978 - val_BBOX_loss: 0.0100 - val_Class_accuracy: 0.9292 - val_BBOX_accuracy: 0.6769
# Epoch 78/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0994 - Class_loss: 0.0933 - BBOX_loss: 0.0061 - Class_accuracy: 0.9603 - BBOX_accuracy: 0.7409 - val_loss: 0.2761 - val_Class_loss: 0.2641 - val_BBOX_loss: 0.0120 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6769
# Epoch 79/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.1789 - Class_loss: 0.1725 - BBOX_loss: 0.0064 - Class_accuracy: 0.9437 - BBOX_accuracy: 0.7355 - val_loss: 0.2477 - val_Class_loss: 0.2377 - val_BBOX_loss: 0.0100 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6892
# Epoch 80/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0690 - Class_loss: 0.0630 - BBOX_loss: 0.0060 - Class_accuracy: 0.9855 - BBOX_accuracy: 0.7350 - val_loss: 0.2642 - val_Class_loss: 0.2542 - val_BBOX_loss: 0.0100 - val_Class_accuracy: 0.9446 - val_BBOX_accuracy: 0.6738
# Epoch 81/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.1009 - Class_loss: 0.0945 - BBOX_loss: 0.0063 - Class_accuracy: 0.9689 - BBOX_accuracy: 0.7460 - val_loss: 0.2584 - val_Class_loss: 0.2472 - val_BBOX_loss: 0.0112 - val_Class_accuracy: 0.9323 - val_BBOX_accuracy: 0.6615
# Epoch 82/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.0598 - Class_loss: 0.0535 - BBOX_loss: 0.0063 - Class_accuracy: 0.9776 - BBOX_accuracy: 0.7009 - val_loss: 0.2857 - val_Class_loss: 0.2753 - val_BBOX_loss: 0.0105 - val_Class_accuracy: 0.9169 - val_BBOX_accuracy: 0.5785
# Epoch 83/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0485 - Class_loss: 0.0425 - BBOX_loss: 0.0060 - Class_accuracy: 0.9915 - BBOX_accuracy: 0.7296 - val_loss: 0.2583 - val_Class_loss: 0.2476 - val_BBOX_loss: 0.0107 - val_Class_accuracy: 0.9323 - val_BBOX_accuracy: 0.6800
# Epoch 84/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.0398 - Class_loss: 0.0328 - BBOX_loss: 0.0070 - Class_accuracy: 0.9857 - BBOX_accuracy: 0.7161 - val_loss: 0.3387 - val_Class_loss: 0.3276 - val_BBOX_loss: 0.0111 - val_Class_accuracy: 0.9046 - val_BBOX_accuracy: 0.6862
# Epoch 85/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0776 - Class_loss: 0.0711 - BBOX_loss: 0.0065 - Class_accuracy: 0.9851 - BBOX_accuracy: 0.7283 - val_loss: 0.2636 - val_Class_loss: 0.2535 - val_BBOX_loss: 0.0101 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6800
# Epoch 86/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0965 - Class_loss: 0.0910 - BBOX_loss: 0.0055 - Class_accuracy: 0.9716 - BBOX_accuracy: 0.7489 - val_loss: 0.2612 - val_Class_loss: 0.2509 - val_BBOX_loss: 0.0103 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6554
# Epoch 87/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0835 - Class_loss: 0.0780 - BBOX_loss: 0.0055 - Class_accuracy: 0.9720 - BBOX_accuracy: 0.7552 - val_loss: 0.3019 - val_Class_loss: 0.2915 - val_BBOX_loss: 0.0104 - val_Class_accuracy: 0.9231 - val_BBOX_accuracy: 0.6585
# Epoch 88/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0743 - Class_loss: 0.0683 - BBOX_loss: 0.0060 - Class_accuracy: 0.9774 - BBOX_accuracy: 0.7219 - val_loss: 0.2634 - val_Class_loss: 0.2529 - val_BBOX_loss: 0.0105 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6923
# Epoch 89/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0966 - Class_loss: 0.0915 - BBOX_loss: 0.0050 - Class_accuracy: 0.9674 - BBOX_accuracy: 0.7658 - val_loss: 0.2680 - val_Class_loss: 0.2580 - val_BBOX_loss: 0.0100 - val_Class_accuracy: 0.9415 - val_BBOX_accuracy: 0.6892
# Epoch 90/100
# 31/31 [==============================] - 4s 146ms/step - loss: 0.0658 - Class_loss: 0.0602 - BBOX_loss: 0.0056 - Class_accuracy: 0.9826 - BBOX_accuracy: 0.7581 - val_loss: 0.2709 - val_Class_loss: 0.2603 - val_BBOX_loss: 0.0106 - val_Class_accuracy: 0.9354 - val_BBOX_accuracy: 0.6738
# Epoch 91/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0612 - Class_loss: 0.0551 - BBOX_loss: 0.0061 - Class_accuracy: 0.9840 - BBOX_accuracy: 0.7639 - val_loss: 0.2901 - val_Class_loss: 0.2794 - val_BBOX_loss: 0.0107 - val_Class_accuracy: 0.9323 - val_BBOX_accuracy: 0.6831
# Epoch 92/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0434 - Class_loss: 0.0378 - BBOX_loss: 0.0056 - Class_accuracy: 0.9847 - BBOX_accuracy: 0.7657 - val_loss: 0.3060 - val_Class_loss: 0.2954 - val_BBOX_loss: 0.0106 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6646
# Epoch 93/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.0465 - Class_loss: 0.0408 - BBOX_loss: 0.0057 - Class_accuracy: 0.9884 - BBOX_accuracy: 0.7430 - val_loss: 0.3358 - val_Class_loss: 0.3254 - val_BBOX_loss: 0.0103 - val_Class_accuracy: 0.9108 - val_BBOX_accuracy: 0.7077
# Epoch 94/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0646 - Class_loss: 0.0597 - BBOX_loss: 0.0050 - Class_accuracy: 0.9844 - BBOX_accuracy: 0.7623 - val_loss: 0.3541 - val_Class_loss: 0.3439 - val_BBOX_loss: 0.0101 - val_Class_accuracy: 0.9077 - val_BBOX_accuracy: 0.7108
# Epoch 95/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0543 - Class_loss: 0.0489 - BBOX_loss: 0.0053 - Class_accuracy: 0.9816 - BBOX_accuracy: 0.7301 - val_loss: 0.3382 - val_Class_loss: 0.3282 - val_BBOX_loss: 0.0100 - val_Class_accuracy: 0.9077 - val_BBOX_accuracy: 0.7046
# Epoch 96/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.0509 - Class_loss: 0.0457 - BBOX_loss: 0.0053 - Class_accuracy: 0.9882 - BBOX_accuracy: 0.7268 - val_loss: 0.3232 - val_Class_loss: 0.3127 - val_BBOX_loss: 0.0105 - val_Class_accuracy: 0.9200 - val_BBOX_accuracy: 0.6677
# Epoch 97/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.0750 - Class_loss: 0.0700 - BBOX_loss: 0.0050 - Class_accuracy: 0.9760 - BBOX_accuracy: 0.7604 - val_loss: 0.3014 - val_Class_loss: 0.2914 - val_BBOX_loss: 0.0100 - val_Class_accuracy: 0.9292 - val_BBOX_accuracy: 0.6831
# Epoch 98/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0645 - Class_loss: 0.0590 - BBOX_loss: 0.0055 - Class_accuracy: 0.9789 - BBOX_accuracy: 0.7426 - val_loss: 0.2902 - val_Class_loss: 0.2780 - val_BBOX_loss: 0.0122 - val_Class_accuracy: 0.9385 - val_BBOX_accuracy: 0.6431
# Epoch 99/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0467 - Class_loss: 0.0410 - BBOX_loss: 0.0058 - Class_accuracy: 0.9880 - BBOX_accuracy: 0.7607 - val_loss: 0.3630 - val_Class_loss: 0.3530 - val_BBOX_loss: 0.0100 - val_Class_accuracy: 0.9323 - val_BBOX_accuracy: 0.6985
# Epoch 100/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.5753 - Class_loss: 0.5704 - BBOX_loss: 0.0050 - Class_accuracy: 0.8260 - BBOX_accuracy: 0.7873 - val_loss: 0.3372 - val_Class_loss: 0.3274 - val_BBOX_loss: 0.0098 - val_Class_accuracy: 0.9169 - val_BBOX_accuracy: 0.7200

# %%
image = cv2.imread("./agri_data/data/agri_0_1068.jpeg")
image = cv2.resize(image, (shape, shape))
image_1 = np.reshape(image, (1 ,shape, shape, 3))
pred = model.model.predict(image_1)
print(pred[0])
startX = int(pred[1][0][0] * 224)
startY = int(pred[1][0][1] * 224)
endX =   int(pred[1][0][2] * 224)
endY =   int(pred[1][0][3] * 224)
cv2.rectangle(image, (startX, startY), (endX, endY),(0, 255, 0), 2)
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38136\1538224001.py in <module>
#       2 image = cv2.resize(image, (shape, shape))
#       3 image_1 = np.reshape(image, (1 ,shape, shape, 3))
# ----> 4 pred = model.model.predict(image_1)
#       5 print(pred[0])
#       6 startX = int(pred[1][0][0] * 224)
#
# NameError: name 'model' is not defined

# %%
image = cv2.imread("../input/crop-and-weed-detection-data-with-bounding-boxes/agri_data/data/agri_0_2751.jpeg")
image = cv2.resize(image, (shape, shape))
image_1 = np.reshape(image, (1 ,shape, shape, 3))
pred = model.model.predict(image_1)
print(pred[0])
startX = int(pred[1][0][0] * 224)
startY = int(pred[1][0][1] * 224)
endX =   int(pred[1][0][2] * 224)
endY =   int(pred[1][0][3] * 224)
cv2.rectangle(image, (startX, startY), (endX, endY),(0, 255, 0), 2)
plt.imshow(image)
# Out:
# [[9.9998999e-01 1.0066461e-05]]
